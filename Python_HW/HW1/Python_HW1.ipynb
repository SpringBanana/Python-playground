# %% [markdown]
# # Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Даны 2 переменных, в которых хранятся строки произвольной длины: *phrase_1* и *phrase_2*.
# Напишите код, который проверяет какая из этих строк длиннее.

# %% [markdown]
# Примеры работы программы:
# 1.
#
# ```
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
# phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
#
# ```
#
# Результат:
# `Фраза 1 длиннее фразы 2`
# 2.
#
# ```
# phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
# ```
#
# Результат:
# `Фраза 2 длиннее фразы 1`
# 3.
#
# ```
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики'
# ```
#
# Результат:
# `Фразы равной длины`

# %%
string_1 = str(input("Enter a string: "))
string_2 = str(input("Enter another string: "))
if len(string_1) > len(string_2):
    print ("Фраза 1 длиннее фразы 2")
elif len(string_1) == len(string_2):
    print ("Фразы равной длины")
else:
    print ("Фраза 2 длиннее фразы 1")
# Out:
# Enter a string:  Насколько проще было бы писать программы, если бы не заказчики
# Enter another string:  640Кб должно хватить для любых задач. Билл Гейтс (по легенде)
# Фраза 1 длиннее фразы 2

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Дана переменная, в которой хранится число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# Пример работы программы:
# 1.
#
# ```
# year = 2020
# ```
# Результат:
# `Високосный год`
#
# 2.
#
# ```
# year = 2019
# ```
# Результат:
# `Обычный год`

# %%
year = int(input())
if year % 4 == 0:
    print("Високосный год")
else:
    print("Обычный год")
# Out:
#  2020
# Високосный год

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# Пример работы программы:
# 1.
#
# ```
# Введите день:
# 30
#
# Введите месяц:
# Август
# ```
# Результат:
# `Ваш знак зодиака: Дева`
#
# 2.
#
# ```
# Введите день:
# 29
#
# Введите месяц:
# Октябрь
# ```
# Результат:
# `Ваш знак зодиака: Скорпион`

# %%
day = int(input("Введите день:"))
while (day < 1 or day > 31):
    print("Неверное число. Попробуйте еще:")
    day = int(input("Введите день:"))
month = str(input("Введите месяц:"))
month_list = ['Январь', 'Февраль', 'Март', 'Апрель', 'Май', 'Июнь', 'Июль', 'Август', 'Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь']
while not month in month_list:
    print("Неверный месяц. Попробуйте еще:")
    month = str(input("Введите месяц:"))
while (day > 28 and month == month_list[1]):
    print("Неверный день месяца. Попробуйте еще:")
    day = int(input("Введите день:"))
while (day > 30 and month in ['Апрель', 'Июнь', 'Сентябрь', 'Ноябрь']):
    print("Неверный день месяца. Попробуйте еще:")
    day = int(input("Введите день:"))
if (day >= 21 and month == month_list[2]) or (day <= 20 and month == month_list[3]):
    print("Ваш знак зодиака: Овен")
if (day >= 21 and month == month_list[3]) or (day <= 20 and month == month_list[4]):
    print("Ваш знак зодиака: Телец")
if (day >= 21 and month == month_list[4]) or (day <= 21 and month == month_list[5]):
    print("Ваш знак зодиака: Близнецы")
if (day >= 22 and month == month_list[5]) or (day <= 22 and month == month_list[6]):
    print("Ваш знак зодиака: Рак")
if (day >= 23 and month == month_list[6]) or (day <= 22 and month == month_list[7]):
    print("Ваш знак зодиака: Лев")
if (day >= 23 and month == month_list[7]) or (day <= 22 and month == month_list[8]):
    print("Ваш знак зодиака: Дева")
if (day >= 23 and month == month_list[8]) or (day <= 22 and month == month_list[9]):
    print("Ваш знак зодиака: Весы")
if (day >= 23 and month == month_list[9]) or (day <= 22 and month == month_list[10]):
    print("Ваш знак зодиака: Скорпион")
if (day >= 23 and month == month_list[10]) or (day <= 22 and month == month_list[11]):
    print("Ваш знак зодиака: Стрелец")
if (day >= 22 and month == month_list[11]) or (day <= 19 and month == month_list[0]):
    print("Ваш знак зодиака: Козерок")
if (day >= 20 and month == month_list[0]) or (day <= 19 and month == month_list[1]):
    print("Ваш знак зодиака: Водолей")
if (day >= 20 and month == month_list[1]) or (day <= 20 and month == month_list[2]):
    print("Ваш знак зодиака: Рыбы")
# Out:
# Введите день: 29
# Введите месяц: Февраль
# Неверный день месяца. Попробуйте еще:
# Введите день: 28
# Ваш знак зодиака: Рыбы

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры (ширина, длина, высота) хранятся в переменных (в сантиметрах):
#
# Используйте следующие правила:
# - если каждое из трех измерений менее или равно 15 сантиметрам, то выведите на экран "Коробка №1";
# - если **хотя бы одно** из измерений больше 2 метров, то выводите "Упаковка для лыж";
# - если **хотя бы одно** из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите "Коробка №2";
# - во всех остальных случаях выводите "Коробка №3".
#
# Пример работы программы:
# 1.
#
# ```
# width = 15
# length = 55
# height = 15
# ```
# Результат:
# `Коробка №3`
#
# 2.
#
# ```
# width = 45
# length = 205
# height = 45
# ```
# Результат:
# `Упаковка для лыж`

# %%
width = int(input())
length = int(input())
height = int(input())
if (width <= 15 and length <= 15 and height <= 15):
    print("Коробка №1")
elif (width > 200 or length > 200 or height > 200):
    print("Упаковка для лыж")
elif ((width > 15 and width < 50) or (length > 15 and length < 50) or (height > 15 and height < 50)):
    print("Коробка №2")
else:
    print("Коробка №3")
# Out:
#  45
#  205
#  45
# Упаковка для лыж

# %% [markdown]
# ## Задание 5 (необязательное)

# %% [markdown]
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет "счастливым". Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# Примеры работы программы:
# 1. ```number = 123456```
#
# Результат:
# `Несчастливый билет`
#
# 2. ```number = 123321```
#
# Результат:
# `Счастливый билет`

# %%
ticket = int(input())
sum1 = ticket % 10 + ticket % 100 // 10 + ticket % 1000 // 100
sum2 = ticket % 10000 // 1000 + ticket % 100000 // 10000 + ticket % 1000000 // 100000
if (sum1 == sum2):
    print("Счастливый билет")
else:
    print("Несчастливый билет")
# Out:
#  123321
# Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)

# %% [markdown]
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник).
# Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# - если пользователь выбрал круг, запрашиваем его радиус,
# - если треугольник – длины трех его сторон;
# - если прямоугольник – длины двух его сторон.
#
# Пример работы программы:
# 1.
#
# ```
# Введите тип фигуры:
# Круг
#
# Введите радиус круга:
# 10
# ```
# Результат:
# `Площадь круга: 314.16`
#
# 2.
#
# ```
# Введите тип фигуры:
# Треугольник
#
# Введите длину стороны A:
# 2
#
# Введите длину стороны B:
# 2
#
# Введите длину стороны C:
# 3
# ```
# Результат:
# `Площадь треугольника: 1.98`

# %%
shape = str(input("Введите тип фигуры"))
while not shape in ['Круг', 'Треугольник', 'Прямоугольник']:
    print("Неверный тип фигуры. Попробуйте еще:")
    shape = str(input("Введите тип фигуры"))
if shape == "Круг":
    radius = int(input("Введите радиус круга:"))
    while radius <= 0:
        print("Неверный радиус. Попробуйте еще:")
        radius = int(input("Введите радиус круга:"))
    print("Площадь круга: ", radius**2 * 3.14)
elif shape == "Треугольник":
    side_a = int(input("Введите длину стороны A:"))
    side_b = int(input("Введите длину стороны B:"))
    side_c = int(input("Введите длину стороны C:"))
    while (side_a <= 0 or side_b <= 0 or side_c <= 0) or not (side_a + side_b > side_c and side_a + side_c > side_b and side_b + side_c > side_a):
        print("Неверная длина стороны. Попробуйте еще:")
        side_a = int(input("Введите длину стороны A:"))
        side_b = int(input("Введите длину стороны B:"))
        side_c = int(input("Введите длину стороны C:"))
    semiperimetr = (side_a + side_b + side_c) / 2
    area = (semiperimetr * (semiperimetr - side_a) * (semiperimetr - side_b) * (semiperimetr - side_c)) ** 0.5
    print("Площаль треугольника: ", area)
elif shape == "Прямоугольник":
    side_a = int(input("Введите длину стороны A:"))
    side_b = int(input("Введите длину стороны B:"))
    while (side_a <= 0 or side_b <= 0):
        print("Неверная длина стороны. Попробуйте еще:")
        side_a = int(input("Введите длину стороны A:"))
        side_b = int(input("Введите длину стороны B:"))
    print("Площадь прямоугольника: ", side_a * side_b)
# Out:
# Введите тип фигуры Треугольник
# Введите длину стороны A: 1
# Введите длину стороны B: 2
# Введите длину стороны C: 4
# Неверная длина стороны. Попробуйте еще:
# Введите длину стороны A: 2
# Введите длину стороны B: 3
# Введите длину стороны C: 5
# Неверная длина стороны. Попробуйте еще:
# Введите длину стороны A: 3
# Введите длину стороны B: 4
# Введите длину стороны C: 5
# Площаль треугольника:  6.0
